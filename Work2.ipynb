# %%
from sklearn.datasets import load_digits
from sklearn.datasets import load_iris
from sklearn.datasets import load_wine
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree, export_graphviz
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import graphviz

digits = load_digits()
canser = load_breast_cancer()
iris = load_iris()
wine = load_wine()

# %%
params1 = {'criterion':['gini', 'entropy'], 'splitter' : ['best', 'random'], 'max_depth' : [None, 3, 5, 10], 'min_samples_split' : [2, 5, 10]}
params2 = {'criterion':['gini', 'entropy'], 'n_estimators' : [5,6,7,8,9], 'max_depth' : [None, 3, 5, 10], 'min_samples_split' : [2, 5, 10]}

dataset = digits
print("Датасет цифры")

X_train, X_test, y_train, y_test = train_test_split(dataset.data, dataset.target, test_size=0.3)
gs = GridSearchCV(DecisionTreeClassifier(), params1, cv = 3, verbose=1, scoring="accuracy")
gs.fit(X_train, y_train)

gs2 = GridSearchCV(RandomForestClassifier(), params2, cv = 3, verbose=1, scoring="accuracy")
gs2.fit(X_train, y_train)


best_p1 = gs.best_params_
accur1 = gs.best_score_
best_DTF = gs.best_estimator_
best_p2 = gs2.best_params_
accur2 = gs2.best_score_
print("-----------------------------------------------------------")
print(f"Лучшие параметры для DecisionTreeClassifier: {best_p1} ")
print(f"Лучшая точность: {accur1} ")
print("-----------------------------------------------------------")
print(f"Лучшие параметры для RandomForestClassifier: {best_p2} ")
print(f"Лучшая точность: {accur2} ")

print("Лучший метод: ")
if accur1 > accur2:
  print(f"DecisionTreeClassifier с точностью: {accur1} ")
else:
  print(f"RandomForestClassifier с точностью: {accur2} ")

dot_data = export_graphviz(best_DTF, out_file=None, filled=True, rounded = True, special_characters=True)
graph = graphviz.Source(dot_data)
graph
# Out:
# Датасет цифры
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# -----------------------------------------------------------
# Лучшие параметры для DecisionTreeClassifier: {'criterion': 'entropy', 'max_depth': None, 'min_samples_split': 2, 'splitter': 'best'}
# Лучшая точность: 0.8552108194112967
# -----------------------------------------------------------
# Лучшие параметры для RandomForestClassifier: {'criterion': 'entropy', 'max_depth': None, 'min_samples_split': 2, 'n_estimators': 9}
# Лучшая точность: 0.933969769291965
# Лучший метод:
# RandomForestClassifier с точностью: 0.933969769291965

# %%
dataset = iris
print("Датасет ирисы")

X_train, X_test, y_train, y_test = train_test_split(dataset.data, dataset.target, test_size=0.3)
gs = GridSearchCV(DecisionTreeClassifier(), params1, cv = 3, verbose=1, scoring="accuracy")
gs.fit(X_train, y_train)

gs2 = GridSearchCV(RandomForestClassifier(), params2, cv = 3, verbose=1, scoring="accuracy")
gs2.fit(X_train, y_train)


best_p1 = gs.best_params_
accur1 = gs.best_score_
best_DTF = gs.best_estimator_
best_p2 = gs2.best_params_
accur2 = gs2.best_score_
print("-----------------------------------------------------------")
print(f"Лучшие параметры для DecisionTreeClassifier: {best_p1} ")
print(f"Лучшая точность: {accur1} ")
print("-----------------------------------------------------------")
print(f"Лучшие параметры для RandomForestClassifier: {best_p2} ")
print(f"Лучшая точность: {accur2} ")

print("Лучший метод: ")
if accur1 > accur2:
  print(f"DecisionTreeClassifier с точностью: {accur1} ")
else:
  print(f"RandomForestClassifier с точностью: {accur2} ")

dot_data = export_graphviz(best_DTF, out_file=None, filled=True, rounded = True, special_characters=True)
graph = graphviz.Source(dot_data)
graph
# Out:
# Датасет ирисы
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# -----------------------------------------------------------
# Лучшие параметры для DecisionTreeClassifier: {'criterion': 'entropy', 'max_depth': None, 'min_samples_split': 5, 'splitter': 'random'}
# Лучшая точность: 0.9619047619047619
# -----------------------------------------------------------
# Лучшие параметры для RandomForestClassifier: {'criterion': 'gini', 'max_depth': None, 'min_samples_split': 2, 'n_estimators': 5}
# Лучшая точность: 0.9619047619047619
# Лучший метод:
# RandomForestClassifier с точностью: 0.9619047619047619

# %%
dataset = wine
print("Датасет вино")

X_train, X_test, y_train, y_test = train_test_split(dataset.data, dataset.target, test_size=0.3)
gs = GridSearchCV(DecisionTreeClassifier(), params1, cv = 3, verbose=1, scoring="accuracy")
gs.fit(X_train, y_train)

gs2 = GridSearchCV(RandomForestClassifier(), params2, cv = 3, verbose=1, scoring="accuracy")
gs2.fit(X_train, y_train)


best_p1 = gs.best_params_
accur1 = gs.best_score_
best_DTF = gs.best_estimator_
best_p2 = gs2.best_params_
accur2 = gs2.best_score_
print("-----------------------------------------------------------")
print(f"Лучшие параметры для DecisionTreeClassifier: {best_p1} ")
print(f"Лучшая точность: {accur1} ")
print("-----------------------------------------------------------")
print(f"Лучшие параметры для RandomForestClassifier: {best_p2} ")
print(f"Лучшая точность: {accur2} ")

print("Лучший метод: ")
if accur1 > accur2:
  print(f"DecisionTreeClassifier с точностью: {accur1} ")
else:
  print(f"RandomForestClassifier с точностью: {accur2} ")

dot_data = export_graphviz(best_DTF, out_file=None, filled=True, rounded = True, special_characters=True)
graph = graphviz.Source(dot_data)
graph
# Out:
# Датасет вино
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# -----------------------------------------------------------
# Лучшие параметры для DecisionTreeClassifier: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_split': 5, 'splitter': 'random'}
# Лучшая точность: 0.959349593495935
# -----------------------------------------------------------
# Лучшие параметры для RandomForestClassifier: {'criterion': 'gini', 'max_depth': 3, 'min_samples_split': 5, 'n_estimators': 9}
# Лучшая точность: 0.983933410762679
# Лучший метод:
# RandomForestClassifier с точностью: 0.983933410762679

# %%
dataset = canser
print("Датасет рак")

X_train, X_test, y_train, y_test = train_test_split(dataset.data, dataset.target, test_size=0.3)
gs = GridSearchCV(DecisionTreeClassifier(), params1, cv = 3, verbose=1, scoring="accuracy")
gs.fit(X_train, y_train)

gs2 = GridSearchCV(RandomForestClassifier(), params2, cv = 3, verbose=1, scoring="accuracy")
gs2.fit(X_train, y_train)


best_p1 = gs.best_params_
accur1 = gs.best_score_
best_DTF = gs.best_estimator_
best_p2 = gs2.best_params_
accur2 = gs2.best_score_
print("-----------------------------------------------------------")
print(f"Лучшие параметры для DecisionTreeClassifier: {best_p1} ")
print(f"Лучшая точность: {accur1} ")
print("-----------------------------------------------------------")
print(f"Лучшие параметры для RandomForestClassifier: {best_p2} ")
print(f"Лучшая точность: {accur2} ")

print("Лучший метод: ")
if accur1 > accur2:
  print(f"DecisionTreeClassifier с точностью: {accur1} ")
else:
  print(f"RandomForestClassifier с точностью: {accur2} ")

dot_data = export_graphviz(best_DTF, out_file=None, filled=True, rounded = True, special_characters=True)
graph = graphviz.Source(dot_data)
graph
# Out:
# Датасет рак
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# -----------------------------------------------------------
# Лучшие параметры для DecisionTreeClassifier: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_split': 5, 'splitter': 'best'}
# Лучшая точность: 0.9522100706311232
# -----------------------------------------------------------
# Лучшие параметры для RandomForestClassifier: {'criterion': 'entropy', 'max_depth': None, 'min_samples_split': 5, 'n_estimators': 8}
# Лучшая точность: 0.9672666514771778
# Лучший метод:
# RandomForestClassifier с точностью: 0.9672666514771778
