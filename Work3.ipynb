# %%
from sklearn.datasets import load_digits
from sklearn.datasets import load_iris
from sklearn.datasets import load_wine
from sklearn.datasets import load_breast_cancer
from sklearn.cluster import KMeans, MeanShift, AffinityPropagation, DBSCAN, OPTICS
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
import warnings
import numpy as np

# %%
warnings.filterwarnings("ignore")

digits = load_digits()
canser = load_breast_cancer()
iris = load_iris()
wine = load_wine()
datasets = [digits, canser, iris, wine]
dss = ["Цифры", "Рак", "Ирисы", "Вино"]
mts = ['euclidean', 'manhattan', 'cosine']

for ds in range(4):
  print("\n\nDataset: ", dss[ds])
  X = datasets[ds].data
  y = datasets[ds].target
  scaler = StandardScaler()
  X = scaler.fit_transform(X)
  for metric in mts:
    print("\nМетрика: ", metric)
    for n in range(2, 5):
      model = KMeans(n_clusters = n)
      model.fit(X)
      y_pred = model.predict(X)
      adj = metrics.adjusted_rand_score(y, y_pred)
      sil = metrics.silhouette_score(X, y_pred, metric = metric)
      print("---------------------------------------")
      print(f"Метод KMeans, Кол-во кластеров: {n}")
      print(f"Cкорректированный индекс Рэнда: {adj}")
      print(f"Силуэт: {sil}")

    model = MeanShift()
    model.fit(X)
    y_pred = model.predict(X)
    adj = metrics.adjusted_rand_score(y, y_pred)
    sil = metrics.silhouette_score(X, y_pred, metric = metric)
    print("---------------------------------------")
    print(f"Метод MeanShift")
    print(f"Cкорректированный индекс Рэнда: {adj:.3f}")
    print(f"Силуэт: {sil}")

    if metric == 'cosine':
        model = AffinityPropagation(affinity = 'precomputed')
        similarity_matrix = cosine_similarity(X)
        model.fit(similarity_matrix)
    else:
        model = AffinityPropagation(affinity = 'euclidean')
        model.fit(X)
    y_pred = model.labels_
    adj = metrics.adjusted_rand_score(y, y_pred)
    sil = metrics.silhouette_score(X, y_pred, metric = metric)
    print("---------------------------------------")
    print(f"Метод AffinityPropagation, Метрика: {metric}")
    print(f"Cкорректированный индекс Рэнда: {adj:.3f}")
    print(f"Силуэт: {sil}")



    model = DBSCAN(metric = metric)
    model.fit(X)
    y_pred = model.labels_
    num_labels = len(np.unique(y_pred))
    if num_labels >= 2:
      adj = metrics.adjusted_rand_score(y, y_pred)
      sil = metrics.silhouette_score(X, y_pred, metric = metric)
      print("---------------------------------------")
      print(f"Метод MeanShift")
      print(f"Cкорректированный индекс Рэнда: {adj:.3f}")
      print(f"Силуэт: {sil}")



    model = OPTICS(metric = metric)
    model.fit(X)
    y_pred = model.labels_
    adj = metrics.adjusted_rand_score(y, y_pred)
    sil = metrics.silhouette_score(X, y_pred, metric = metric)
    print("---------------------------------------")
    print(f"Метод MeanShift")
    print(f"Cкорректированный индекс Рэнда: {adj:.3f}")
    print(f"Силуэт: {sil}")
# Out:
# Dataset:  Цифры
# Метрика:  euclidean
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 2
# Cкорректированный индекс Рэнда: 0.1264026069539568
# Силуэт: 0.10564011752045978
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 3
# Cкорректированный индекс Рэнда: 0.24671048356318925
# Силуэт: 0.10445567448142226
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 4
# Cкорректированный индекс Рэнда: 0.2902814581050722
# Силуэт: 0.09540834891837935
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: 0.000
# Силуэт: 0.3128806756982816
# ---------------------------------------
# Метод AffinityPropagation, Метрика: euclidean
# Cкорректированный индекс Рэнда: 0.154
# Силуэт: 0.10534489509840632
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: 0.004
# Силуэт: -0.2593179267967185
# Метрика:  manhattan
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 2
# Cкорректированный индекс Рэнда: 0.12661376720008016
# Силуэт: 0.14235437642615298
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 3
# Cкорректированный индекс Рэнда: 0.22325028999487387
# Силуэт: 0.13951986555508433
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 4
# Cкорректированный индекс Рэнда: 0.28855659437167935
# Силуэт: 0.14107649793832078
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: 0.000
# Силуэт: 0.06781539039553014
# ---------------------------------------
# Метод AffinityPropagation, Метрика: manhattan
# Cкорректированный индекс Рэнда: 0.154
# Силуэт: 0.10599349409421635
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: 0.002
# Силуэт: -0.32366494809557356
# Метрика:  cosine
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 2
# Cкорректированный индекс Рэнда: 0.12661376720008016
# Силуэт: 0.1774723032621936
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 3
# Cкорректированный индекс Рэнда: 0.23420803308796087
# Силуэт: 0.19379106817088632
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 4
# Cкорректированный индекс Рэнда: 0.286164224668672
# Силуэт: 0.19970946539934756
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: 0.000
# Силуэт: -0.17259617220664195
# ---------------------------------------
# Метод AffinityPropagation, Метрика: cosine
# Cкорректированный индекс Рэнда: 0.144
# Силуэт: 0.19886525083860618
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: 0.000
# Силуэт: 0.008012010729640173
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: 0.005
# Силуэт: -0.36733175696226567
#
#
# Dataset:  Рак
# Метрика:  euclidean
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 2
# Cкорректированный индекс Рэнда: 0.6707206476880808
# Силуэт: 0.3449740051034408
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 3
# Cкорректированный индекс Рэнда: 0.510670959369618
# Силуэт: 0.3143840098608098
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 4
# Cкорректированный индекс Рэнда: 0.584068899762848
# Силуэт: 0.2726156083675339
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: 0.128
# Силуэт: 0.2653848600978455
# ---------------------------------------
# Метод AffinityPropagation, Метрика: euclidean
# Cкорректированный индекс Рэнда: 0.049
# Силуэт: 0.08700544652658676
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: 0.028
# Силуэт: -0.0956040536590282
# Метрика:  manhattan
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 2
# Cкорректированный индекс Рэнда: 0.6536246043910179
# Силуэт: 0.38142317391815783
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 3
# Cкорректированный индекс Рэнда: 0.510670959369618
# Силуэт: 0.33459133228421073
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 4
# Cкорректированный индекс Рэнда: 0.5550461093012312
# Силуэт: 0.31912483163511257
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: 0.128
# Силуэт: 0.23435775960412533
# ---------------------------------------
# Метод AffinityPropagation, Метрика: manhattan
# Cкорректированный индекс Рэнда: 0.049
# Силуэт: 0.07701700121959794
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: 0.038
# Силуэт: -0.09892058346757088
# Метрика:  cosine
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 2
# Cкорректированный индекс Рэнда: 0.6707206476880808
# Силуэт: 0.4725497711101807
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 3
# Cкорректированный индекс Рэнда: 0.510670959369618
# Силуэт: 0.38822808539505926
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 4
# Cкорректированный индекс Рэнда: 0.5548500861793579
# Силуэт: 0.28676911120672605
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: 0.128
# Силуэт: -0.1332065658718202
# ---------------------------------------
# Метод AffinityPropagation, Метрика: cosine
# Cкорректированный индекс Рэнда: 0.056
# Силуэт: 0.16819720663320262
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: -0.011
# Силуэт: -0.5530696817814365
#
#
# Dataset:  Ирисы
# Метрика:  euclidean
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 2
# Cкорректированный индекс Рэнда: 0.5681159420289855
# Силуэт: 0.5817500491982808
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 3
# Cкорректированный индекс Рэнда: 0.6201351808870379
# Силуэт: 0.45994823920518635
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 4
# Cкорректированный индекс Рэнда: 0.44180032654288676
# Силуэт: 0.38517417630641415
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: 0.568
# Силуэт: 0.5817500491982808
# ---------------------------------------
# Метод AffinityPropagation, Метрика: euclidean
# Cкорректированный индекс Рэнда: 0.370
# Силуэт: 0.34129964541909497
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: 0.442
# Силуэт: 0.35651648142700726
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: 0.051
# Силуэт: -0.300864934206103
# Метрика:  manhattan
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 2
# Cкорректированный индекс Рэнда: 0.5681159420289855
# Силуэт: 0.620856286288675
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 3
# Cкорректированный индекс Рэнда: 0.6201351808870379
# Силуэт: 0.49585177684295917
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 4
# Cкорректированный индекс Рэнда: 0.4728177114181946
# Силуэт: 0.3930827382415973
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: 0.568
# Силуэт: 0.620856286288675
# ---------------------------------------
# Метод AffinityPropagation, Метрика: manhattan
# Cкорректированный индекс Рэнда: 0.370
# Силуэт: 0.3320602691110307
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: 0.123
# Силуэт: -0.24350130976531895
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: 0.090
# Силуэт: -0.20369786921045355
# Метрика:  cosine
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 2
# Cкорректированный индекс Рэнда: 0.5681159420289855
# Силуэт: 0.7373869860909995
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 3
# Cкорректированный индекс Рэнда: 0.6201351808870379
# Силуэт: 0.6430877748444538
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 4
# Cкорректированный индекс Рэнда: 0.4728177114181946
# Силуэт: 0.5514699125974564
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: 0.568
# Силуэт: 0.7373869860909995
# ---------------------------------------
# Метод AffinityPropagation, Метрика: cosine
# Cкорректированный индекс Рэнда: 0.333
# Силуэт: 0.5295527595462013
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: 0.080
# Силуэт: -0.17744760141105867
#
#
# Dataset:  Вино
# Метрика:  euclidean
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 2
# Cкорректированный индекс Рэнда: 0.37431449262136857
# Силуэт: 0.2593169555318255
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 3
# Cкорректированный индекс Рэнда: 0.8974949815093207
# Силуэт: 0.2848589191898987
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 4
# Cкорректированный индекс Рэнда: 0.7645635004420589
# Силуэт: 0.2586075384934024
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: -0.006
# Силуэт: 0.22447619269259034
# ---------------------------------------
# Метод AffinityPropagation, Метрика: euclidean
# Cкорректированный индекс Рэнда: 0.273
# Силуэт: 0.12094943296335095
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: 0.036
# Силуэт: -0.13363975991065313
# Метрика:  manhattan
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 2
# Cкорректированный индекс Рэнда: 0.38872424979619347
# Силуэт: 0.3040627050195275
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 3
# Cкорректированный индекс Рэнда: 0.8974949815093207
# Силуэт: 0.31352080929967746
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 4
# Cкорректированный индекс Рэнда: 0.7727955905200289
# Силуэт: 0.2728877690873319
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: -0.006
# Силуэт: 0.17551286039895925
# ---------------------------------------
# Метод AffinityPropagation, Метрика: manhattan
# Cкорректированный индекс Рэнда: 0.273
# Силуэт: 0.11584699707027836
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: 0.037
# Силуэт: -0.24215444666596678
# Метрика:  cosine
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 2
# Cкорректированный индекс Рэнда: 0.38872424979619347
# Силуэт: 0.4151222467389302
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 3
# Cкорректированный индекс Рэнда: 0.8974949815093207
# Силуэт: 0.4692654975250367
# ---------------------------------------
# Метод KMeans, Кол-во кластеров: 4
# Cкорректированный индекс Рэнда: 0.7645635004420589
# Силуэт: 0.4270281967531101
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: -0.006
# Силуэт: 0.005904182143524101
# ---------------------------------------
# Метод AffinityPropagation, Метрика: cosine
# Cкорректированный индекс Рэнда: 0.218
# Силуэт: 0.24564574614141194
# ---------------------------------------
# Метод MeanShift
# Cкорректированный индекс Рэнда: 0.016
# Силуэт: -0.37417858262035586
